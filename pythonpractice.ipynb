# %%
student_count = 1000
print(student_count)
# Out:
# 1000

# %%
x=10
y=x+2
print(y)
# Out:
# 12

# %%
course = "Python Programming"
print(course)
# Out:
# Python Programming

# %%
len(course)
# Out:
# 18

# %%
print(len(course))
# Out:
# 18

# %%
print(course[0])
# Out:
# P

# %%
print(course[-1])
# Out:
# g

# %%
print(course[0:3])
# Out:
# Pyt

# %%
print(course[-1:3])

# %%
print(course[0:])
# Out:
# Python Programming

# %%
print(course[:3])
# Out:
# Pyt

# %%
print(course[-1:])
# Out:
# g

# %%
print(course[-1:-3])

# %%
course = 'Python "Programming"'
print(course)
# Out:
# Python "Programming"

# %%
course = "Python \"Programming"
print(course)
# Out:
# Python "Programming

# %%
print(course)
# Out:
# Python "Programming"

# %%
first = "Ramgopal"
last = "Yalla"
full = first + " " + last
print(full)
# Out:
# Ramgopal Yalla

# %%
first = "Ramgopal"
last = "Yalla"
full = f"{first} {last}"
print(full)
# Out:
# Ramgopal Yalla

# %%
first = "Ramgopal"
last = "Yalla"
full = f"{first} {last}"
print(full)
print(len(full))
# Out:
# Ramgopal Yalla
# 14

# %%
print(full.lower())
print(full)
print(full.upper())
# Out:
# ramgopal yalla
# Ramgopal Yalla
# RAMGOPAL YALLA

# %%
print(full.title())
# Out:
# Ramgopal Yalla

# %%
print(full.strip())
# Out:
# Ramgopal Yalla

# %%
print(full.find("Yall"))
# Out:
# 9

# %%
print(full.replace("Y","T"))
# Out:
# Ramgopal Talla

# %%
print(full.replace("Y","T"))
# Out:
# Ramgopal Talla
